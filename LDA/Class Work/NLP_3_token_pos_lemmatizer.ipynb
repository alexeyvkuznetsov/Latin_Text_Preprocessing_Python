# %% [markdown]
# <a href="https://colab.research.google.com/github/aashu1328/Natural-language-Processing/blob/master/NLP_3_token_pos_lemmatizer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from nltk import word_tokenize 
data = "All work and no play makes jack a dull boy, all work and no play"
print(word_tokenize(data))
# Out:
# ['All', 'work', 'and', 'no', 'play', 'makes', 'jack', 'a', 'dull', 'boy', ',', 'all', 'work', 'and', 'no', 'play']

# %%
from nltk import sent_tokenize 
data1= "I am a good girl "+" I like to play piano"
print(sent_tokenize(data1))
# Out:
# ['I am a good girl  I like to play piano']

# %%
import pandas as pd 
df=pd.read_json("http://snap.stanford.edu/data/amazon/productGraph/categoryFiles/reviews_Office_Products_5.json.gz",lines= True,orient='values')

# %%
df1=df.reviewText[1]
word_token=word_tokenize(df1)

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
from nltk.stem import WordNetLemmatizer 
lemmatizer = WordNetLemmatizer()
print("rocks :", lemmatizer.lemmatize("rocks")) 
print("corpora :", lemmatizer.lemmatize("corpora"))
# Out:
# rocks : rock
# corpora : corpus

# %%
df1=df.reviewText[1]
for word in word_token:
     z=lemmatizer.lemmatize(word)
     print(z)
# Out:
# WHY
# THIS
# BELATED
# REVIEW
# ?
# I
# feel
# very
# obliged
# to
# share
# my
# view
# about
# this
# old
# workhorse
# ,
# the
# HP12C
# GOLD
# at
# it
# 25th
# anniversary
# and
# my
# 1Oth
# year
# a
# a
# satisfied
# ower
# user
# and
# fan
# .
# Especially
# after
# sharing
# my
# frank
# view
# on
# Amazon
# about
# two
# of
# it
# three
# successor
# on
# Amazon.com
# ,
# burying
# the
# HP12c
# Platinum
# (
# 2004
# 1st
# release
# ,
# HP12cP
# )
# and
# praising
# the
# HP12c
# Platiunum
# Anniversary
# Edition
# (
# 2006
# 3rd
# release
# ,
# HP12cPAE
# or
# HP12cPA
# )
# .To
# the
# majority
# of
# HP
# 12c
# calculator
# owner
# and
# fan
# ,
# including
# the
# non-techkie
# nerd
# like
# myself
# ,
# the
# name
# Hewlett-Packard
# To
# the
# majority
# of
# HP
# 12c
# calculator
# owner
# and
# fan
# .
# The
# brandname
# of
# Hewlett-Packard
# is
# synonymous
# with
# the
# highest
# quality
# and
# best
# range
# offered
# in
# handheld
# electronic
# business
# ...

# %%
nltk.download('averaged_perceptron_tagger')
nltk.pos_tag(word_token)
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [('WHY', 'WRB'),
#  ('THIS', 'NNP'),
#  ('BELATED', 'NNP'),
#  ('REVIEW', 'NNP'),
#  ('?', '.'),
#  ('I', 'PRP'),
#  ('feel', 'VBP'),
#  ('very', 'RB'),
#  ('obliged', 'VBN'),
#  ('to', 'TO'),
#  ('share', 'NN'),
#  ('my', 'PRP$'),
#  ('views', 'NNS'),
#  ('about', 'IN'),
#  ('this', 'DT'),
#  ('old', 'JJ'),
#  ('workhorse', 'NN'),
#  (',', ','),
#  ('the', 'DT'),
#  ('HP12C', 'NNP'),
#  ('GOLD', 'NNP'),
#  ('at', 'IN'),
#  ('its', 'PRP$'),
#  ('25th', 'CD'),
#  ('anniversary', 'NN'),
#  ('and', 'CC'),
#  ('my', 'PRP$'),
#  ('1Oth', 'CD'),
#  ('year', 'NN'),
#  ('as', 'IN'),
#  ('a', 'DT'),
#  ('satisfied', 'JJ'),
#  ('ower', 'JJR'),
#  ('user', 'NN'),
#  ('and', 'CC'),
#  ('fan', 'NN'),
#  ('.', '.'),
#  ('Especially', 'RB'),
#  ('after', 'IN'),
#  ('sharing', 'VBG'),
#  ('my', 'PRP$'),
# ...

# %%
def all_3(text):
  final=dict()
  word_token=word_tokenize(text)
  word_lemmatize=[lemmatizer.lemmatize(word) for word in word_token]
     #print(word_lemmatize)
  word_tag=nltk.pos_tag(word_token)   
  final={'token': word_token,'lemmat':word_lemmatize,'word_tag':word_tag}
  return final

# %%
all_3(df1)
# Out:
# {'lemmat': ['WHY',
#   'THIS',
#   'BELATED',
#   'REVIEW',
#   '?',
#   'I',
#   'feel',
#   'very',
#   'obliged',
#   'to',
#   'share',
#   'my',
#   'view',
#   'about',
#   'this',
#   'old',
#   'workhorse',
#   ',',
#   'the',
#   'HP12C',
#   'GOLD',
#   'at',
#   'it',
#   '25th',
#   'anniversary',
#   'and',
#   'my',
#   '1Oth',
#   'year',
#   'a',
#   'a',
#   'satisfied',
#   'ower',
#   'user',
#   'and',
#   'fan',
#   '.',
#   'Especially',
#   'after',
#   'sharing',
#   'my',
#   'frank',
#   'view',
#   'on',
#   'Amazon',
#   'about',
#   'two',
#   'of',
#   'it',
#   'three',
#   'successor',
#   'on',
#   'Amazon.com',
#   ',',
#   'burying',
#   'the',
#   'HP12c',
#   'Platinum',
#   '(',
#   '2004',
#   '1st',
#   'release',
#   ',',
#   'HP12cP',
#   ')',
#   'and',
#   'praising',
#   'the',
#   'HP12c',
#   'Platiunum',
#   'Anniversary',
#   'Edition',
#   '(',
#   '2006',
#   '3rd',
#   'release',
#   ',',
#   'HP12cPAE',
#   'or',
#   'HP12cPA',
# ...

# %%
def adj (txt):
   word_tag=nltk.pos_tag(txt.split())
   adj_list=['JJ','JJS','JJR']
   final_list=[a[0] for a in word_tag if a[1]in adj_list] 
   return final_list

# %%
adj(df1)
# Out:
# ['old',
#  'satisfied',
#  'ower',
#  'frank',
#  'non-techkie',
#  'synonymous',
#  'highest',
#  'best',
#  'handheld',
#  'electronic',
#  'financial',
#  'first',
#  'personal',
#  'users.To',
#  '"gold"',
#  'other',
#  'matured',
#  'only',
#  'longest',
#  'electronic',
#  'best',
#  'proven',
#  'unchanged',
#  'indispensable',
#  '"portable"',
#  'finance-business',
#  'handy',
#  'portable',
#  'personal',
#  'serious',
#  'ultimate',
#  'solution,',
#  'continued',
#  'disappointing',
#  'least',
#  'major',
#  'futile',
#  'own',
#  'rightful',
#  'financial',
#  'following',
#  'golden',
#  'same',
#  'paramount',
#  'users.GOLDEN',
#  'right.',
#  'ultimate',
#  'ardent',
#  'financial',
#  'scientific',
#  'genuine',
#  'anniversary',
#  'nice',
#  'golden',
#  '50th',
#  'ultimate',
#  'anniversary',
#  'nice',
#  'lucrative',
#  '50th',
#  'other',
#  'original',
#  'please',
#  'old']
